# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings

warnings.filterwarnings("ignore")
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Activation,Flatten,Reshape
from keras.layers import Embedding
from keras.layers import LSTM
from keras.preprocessing.text import Tokenizer
import csv
from keras.models import Model
#import keras
from keras import backend as k
from keras.layers import Input,Concatenate,Dropout,Dense,BatchNormalization,Conv1D
from keras.layers import Input
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
#from tensorflow.keras.merge import concatenate
#import tensorflow as tf
from keras.preprocessing.sequence import pad_sequences
import scipy
from keras.initializers import he_normal,glorot_normal
from keras.regularizers import l1,l2
from tensorflow.python.keras.callbacks import TensorBoard
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint,LearningRateScheduler,ReduceLROnPlateau
from time import time
from tensorflow.keras.utils import plot_model

# %%
train=pd.read_csv('/content/drive/MyDrive/Tweets Disaster /train.csv')
test=pd.read_csv('/content/drive/MyDrive/Tweets Disaster /test.csv')
print('Train shape:-',train.shape)
print('Test shape:-',test.shape)
# Out:
# Train shape:- (7613, 5)
# Test shape:- (3263, 4)

# %%
train['keyword']=train['keyword'].fillna('No keyword')
test['keyword']=test['keyword'].fillna('No keyword')

# %%
train['location']=train['location'].fillna('No location')
test['location']=test['location'].fillna('No location')

# %%
train['text']=train['text']+' '+train['keyword']+' '+train['location']
test['text']=test['text']+' '+test['keyword']+' '+test['location']

# %%
import nltk
from tqdm import tqdm
import re
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)
def decontractions(phrase):
    """decontracted takes text and convert contractions into natural form.
     ref: https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python/47091490#47091490"""
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"won\’t", "will not", phrase)
    phrase = re.sub(r"can\’t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)

    phrase = re.sub(r"n\’t", " not", phrase)
    phrase = re.sub(r"\’re", " are", phrase)
    phrase = re.sub(r"\’s", " is", phrase)
    phrase = re.sub(r"\’d", " would", phrase)
    phrase = re.sub(r"\’ll", " will", phrase)
    phrase = re.sub(r"\’t", " not", phrase)
    phrase = re.sub(r"\’ve", " have", phrase)
    phrase = re.sub(r"\’m", " am", phrase)

    return phrase

def preprocess(text_col,stopword):
    preprocessed = []
    for sentence in tqdm(text_col.values):
        # Replace "carriage return" with "space".
        sentence=str(sentence)
        sent = sentence.replace('\\r', ' ')
        # Replace "quotes" with "space".
        sent = sent.replace('\\"', ' ')
        # Replace "line feed" with "space".
        sent = sent.replace('\\n', ' ')
        # Replace characters between words with "space".
        sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
        #remove stop words
        #decontraction
        sent=decontractions(sent)
        #Remove emoji
        sent=deEmojify(sent)
        if stopword:
            sent = ' '.join(e for e in sent.split() if e not in stopwords)
        else:
            sent = ' '.join(e for e in sent.split())
        # to lowercase
        preprocessed.append(sent.lower().strip())
    return preprocessed
train['text']=preprocess(train['text'],stopword=False)
test['text']=preprocess(test['text'],stopword=False)
# Out:
# 100%|██████████| 7613/7613 [00:00<00:00, 10370.59it/s]
# 100%|██████████| 3263/3263 [00:00<00:00, 8290.95it/s]

# %%
train['len_comm']=train['text'].apply(lambda x:len(x.split()))
test['len_comm']=test['text'].apply(lambda x:len(x.split()))

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
def generate_sentiment_scores(data):
    sid = SentimentIntensityAnalyzer()
    neg=[]
    pos=[]
    neu=[]
    comp=[]
    for sentence in tqdm(data['text'].values): 
        sentence_sentiment_score = sid.polarity_scores(sentence)
        comp.append(sentence_sentiment_score['compound'])
        neg.append(sentence_sentiment_score['neg'])
        pos.append(sentence_sentiment_score['pos'])
        neu.append(sentence_sentiment_score['neu'])
    return comp,neg,pos,neu
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
train['comp'],train['neg'],train['pos'],train['neu']=generate_sentiment_scores(train)
test['comp'],test['neg'],test['pos'],test['neu']=generate_sentiment_scores(test)
# Out:
# 100%|██████████| 7613/7613 [00:02<00:00, 3451.49it/s]
# 100%|██████████| 3263/3263 [00:00<00:00, 3445.39it/s]

# %%
y=train['target']
X=train.drop(['target','id'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %%
def pad_text(text,tokenizer,max_len):
    return pad_sequences(tokenizer.texts_to_sequences(text),maxlen=max_len,padding='post')

# %%
from keras.preprocessing.text import Tokenizer
def text_padding(train,test,test_final,max_len):
    token=Tokenizer()
    token.fit_on_texts(train)
    padded_train_text=pad_text(train,token,max_len)
    padded_test_text=pad_text(test,token,max_len)
    padded_test_final_text=pad_text(test_final,token,max_len)
    return padded_train_text,padded_test_text,padded_test_final_text,token

# %%
comm_len=200
train_com_pad,test_com_pad,test_final_com_pad,token_com= text_padding(X_train['text'],X_test['text'],test['text'],comm_len)

# %%
def generate_embedding_matrix(file_location,token):
    embedding_path=file_location
    embedding_dimension=300
    embedding_index={}
    with open(embedding_path,encoding="utf-8") as f:
         for line in f:
             values=line.split()
             word=values[0]
             coefs=np.asarray(values[1:],dtype='float32')
             embedding_index[word]=coefs
    f.close()        
    embedding_matrix=np.zeros((len(token.word_index)+1,embedding_dimension))
    for word, i in token.word_index.items():
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
           embedding_matrix[i] = embedding_vector
    return embedding_matrix

# %%
file_location='/content/drive/MyDrive/glove.6B.300d.txt'
embedding_comm_glove = generate_embedding_matrix(file_location,token_com)
print(embedding_comm_glove.shape)
# Out:
# (18451, 300)

# %%
file_location='/content/drive/MyDrive/wiki-news-300d-1M.vec'
embedding_comm_wiki = generate_embedding_matrix(file_location,token_com)
print(embedding_comm_wiki.shape)
# Out:
# (18451, 300)

# %%
# %%time
from sklearn.preprocessing import Normalizer
trans = Normalizer()
X_train_comp=trans.fit_transform(X_train['comp'].values.reshape(-1,1))
X_test_comp=trans.transform(X_test['comp'].values.reshape(-1,1))
test_comp=trans.transform(test['comp'].values.reshape(-1,1))
# Out:
# CPU times: user 3.17 ms, sys: 0 ns, total: 3.17 ms
# Wall time: 5.66 ms

# %%
# %%time
from sklearn.preprocessing import Normalizer
trans = Normalizer()
X_train_neg=trans.fit_transform(X_train['neg'].values.reshape(-1,1))
X_test_neg=trans.transform(X_test['neg'].values.reshape(-1,1))
test_neg=trans.transform(test['neg'].values.reshape(-1,1))
# Out:
# CPU times: user 3.76 ms, sys: 0 ns, total: 3.76 ms
# Wall time: 3.04 ms

# %%
# %%time
from sklearn.preprocessing import Normalizer
trans = Normalizer()
X_train_pos=trans.fit_transform(X_train['pos'].values.reshape(-1,1))
X_test_pos=trans.transform(X_test['pos'].values.reshape(-1,1))
test_pos=trans.transform(test['pos'].values.reshape(-1,1))
# Out:
# CPU times: user 2.01 ms, sys: 0 ns, total: 2.01 ms
# Wall time: 1.98 ms

# %%
# %%time
from sklearn.preprocessing import Normalizer
trans = Normalizer()
X_train_neu=trans.fit_transform(X_train['neu'].values.reshape(-1,1))
X_test_neu=trans.transform(X_test['neu'].values.reshape(-1,1))
test_neu=trans.transform(test['neu'].values.reshape(-1,1))
# Out:
# CPU times: user 1.31 ms, sys: 24 µs, total: 1.33 ms
# Wall time: 1.34 ms

# %%
# %%time
from sklearn.preprocessing import Normalizer
trans = Normalizer()
X_train_len=trans.fit_transform(X_train['len_comm'].values.reshape(-1,1))
X_test_len=trans.transform(X_test['len_comm'].values.reshape(-1,1))
test_len=trans.transform(test['len_comm'].values.reshape(-1,1))
# Out:
# CPU times: user 2.97 ms, sys: 0 ns, total: 2.97 ms
# Wall time: 2.49 ms

# %%
# %%time
from scipy.sparse import hstack
train_s=np.concatenate((X_train_comp,X_train_neg,X_train_pos,X_train_neu,X_train_len),axis=1)
test_s=np.concatenate((X_test_comp,X_test_neg,X_test_pos,X_test_neu,X_test_len),axis=1)
test_final=np.concatenate((test_comp,test_neg,test_pos,test_neu,test_len),axis=1)
# Out:
# CPU times: user 1.74 ms, sys: 0 ns, total: 1.74 ms
# Wall time: 1.31 ms

# %%
train_val=[train_com_pad,train_s]
test_val=[test_com_pad,test_s]
test_final_val=[test_final_com_pad,test_final]

# %%
from sklearn.preprocessing import LabelEncoder
from keras.initializers import glorot_uniform,glorot_normal
from keras.layers import MaxPooling1D
from keras.layers import concatenate
def Deep_CNN1D(comm_len,token_com):
    input_1 = Input(shape=(comm_len,),name = 'Text')
    emb_text_layer_1 = Embedding(len(token_com.word_index) + 1,300,input_length=comm_len,trainable=False,dtype=tf.float32)(input_1)
    emb_text_layer_1 = Dropout(0.4)(emb_text_layer_1)
    conv1_1 = Conv1D(128,8,1,activation='relu',kernel_initializer=glorot_uniform(seed=42))(emb_text_layer_1)
    max1_1 = MaxPooling1D(pool_size= 4,)(conv1_1)
    conv1_2 = Conv1D(64,4,1,activation='relu',kernel_initializer=glorot_uniform(seed=42))(max1_1)
    max1_2 = MaxPooling1D(4)(conv1_2)
    #lstm_output = LSTM(32, return_sequences = True,name= "LSTM",kernel_initializer=glorot_uniform(seed=42))(max2)
    flatten_1 = Flatten()(max1_2)


    # creating layers for numerical columns
    input_3 = Input(shape=(5,), name = "input_numerical")
    dense_num_layer = Dense(128, activation = "relu")(input_3)

    concatenated_layer = concatenate([flatten_1,dense_num_layer],axis=-1)

    # creating further layers
    x = Dense(128, activation = 'relu',kernel_initializer=glorot_uniform(seed=42))(concatenated_layer)
    x = Dense(64, activation = 'relu',kernel_initializer=glorot_uniform(seed=42))(x)
    x = Dense(32, activation = 'relu',kernel_initializer=glorot_uniform(seed=42))(x)
    x = Dense(16, activation = 'relu',kernel_initializer=glorot_uniform(seed=42))(x)
    output = Dense(1, activation = 'sigmoid', name= 'model_output',kernel_initializer=glorot_uniform(seed=42))(x)
    model = Model(inputs = [input_1,input_3], outputs = [output])
    return model

# %%
model_1=Deep_CNN1D(comm_len,token_com)

# %%
tf.keras.utils.plot_model(
    model_1, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')

# %%
import tensorflow as tf
adam = tf.keras.optimizers.Adam(lr=0.0001)
model_1.compile(optimizer=adam, loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.callbacks import *
import os
earlystop = EarlyStopping(monitor = 'val_accuracy',  mode="max",min_delta = 0, patience = 20,verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.25, patience = 2, verbose = 1)

callbacks = [reduce_lr,earlystop]

# %%
hitory=model_1.fit(x=train_val,y=y_train,epochs=50,batch_size=128,validation_data=(test_val, y_test),callbacks=callbacks)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 11s 53ms/step - loss: 0.6793 - accuracy: 0.5703 - val_loss: 0.6730 - val_accuracy: 0.5705 - lr: 1.0000e-04
# Epoch 2/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.6711 - accuracy: 0.5703 - val_loss: 0.6665 - val_accuracy: 0.5705 - lr: 1.0000e-04
# Epoch 3/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.6656 - accuracy: 0.5716 - val_loss: 0.6587 - val_accuracy: 0.6195 - lr: 1.0000e-04
# Epoch 4/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.6569 - accuracy: 0.6014 - val_loss: 0.6465 - val_accuracy: 0.6546 - lr: 1.0000e-04
# Epoch 5/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.6437 - accuracy: 0.6436 - val_loss: 0.6323 - val_accuracy: 0.6743 - lr: 1.0000e-04
# Epoch 6/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.6315 - accuracy: 0.6543 - val_loss: 0.6234 - val_accuracy: 0.6703 - lr: 1.0000e-04
# Epoch 7/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.6254 - accuracy: 0.6570 - val_loss: 0.6178 - val_accuracy: 0.6804 - lr: 1.0000e-04
# Epoch 8/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.6184 - accuracy: 0.6712 - val_loss: 0.6123 - val_accuracy: 0.6782 - lr: 1.0000e-04
# Epoch 9/50
# 42/42 [==============================] - 2s 37ms/step - loss: 0.6164 - accuracy: 0.6714 - val_loss: 0.6091 - val_accuracy: 0.6817 - lr: 1.0000e-04
# Epoch 10/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.6077 - accuracy: 0.6816 - val_loss: 0.6043 - val_accuracy: 0.6870 - lr: 1.0000e-04
# Epoch 11/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5984 - accuracy: 0.6896 - val_loss: 0.5967 - val_accuracy: 0.6944 - lr: 1.0000e-04
# Epoch 12/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.5889 - accuracy: 0.7035 - val_loss: 0.5912 - val_accuracy: 0.6983 - lr: 1.0000e-04
# Epoch 13/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.5766 - accuracy: 0.7140 - val_loss: 0.5806 - val_accuracy: 0.7080 - lr: 1.0000e-04
# Epoch 14/50
# 42/42 [==============================] - 2s 40ms/step - loss: 0.5583 - accuracy: 0.7260 - val_loss: 0.5683 - val_accuracy: 0.7246 - lr: 1.0000e-04
# Epoch 15/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.5379 - accuracy: 0.7403 - val_loss: 0.5610 - val_accuracy: 0.7189 - lr: 1.0000e-04
# Epoch 16/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.5111 - accuracy: 0.7649 - val_loss: 0.5520 - val_accuracy: 0.7307 - lr: 1.0000e-04
# Epoch 17/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.4970 - accuracy: 0.7758 - val_loss: 0.5421 - val_accuracy: 0.7325 - lr: 1.0000e-04
# Epoch 18/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.4754 - accuracy: 0.7825 - val_loss: 0.5387 - val_accuracy: 0.7369 - lr: 1.0000e-04
# Epoch 19/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.4556 - accuracy: 0.7992 - val_loss: 0.5320 - val_accuracy: 0.7465 - lr: 1.0000e-04
# Epoch 20/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.4366 - accuracy: 0.8153 - val_loss: 0.5359 - val_accuracy: 0.7386 - lr: 1.0000e-04
# Epoch 21/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.4168 - accuracy: 0.8237
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 42/42 [==============================] - 2s 41ms/step - loss: 0.4155 - accuracy: 0.8245 - val_loss: 0.5309 - val_accuracy: 0.7421 - lr: 1.0000e-04
# Epoch 22/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3864 - accuracy: 0.8491 - val_loss: 0.5271 - val_accuracy: 0.7439 - lr: 2.5000e-05
# Epoch 23/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3940 - accuracy: 0.8359
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 42/42 [==============================] - 2s 39ms/step - loss: 0.3937 - accuracy: 0.8362 - val_loss: 0.5294 - val_accuracy: 0.7417 - lr: 2.5000e-05
# Epoch 24/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3825 - accuracy: 0.8478 - val_loss: 0.5238 - val_accuracy: 0.7482 - lr: 6.2500e-06
# Epoch 25/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3783 - accuracy: 0.8506 - val_loss: 0.5252 - val_accuracy: 0.7474 - lr: 6.2500e-06
# Epoch 26/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3786 - accuracy: 0.8443
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3778 - accuracy: 0.8450 - val_loss: 0.5248 - val_accuracy: 0.7474 - lr: 6.2500e-06
# Epoch 27/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3777 - accuracy: 0.8484 - val_loss: 0.5238 - val_accuracy: 0.7469 - lr: 1.5625e-06
# Epoch 28/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3787 - accuracy: 0.8493
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3780 - accuracy: 0.8501 - val_loss: 0.5238 - val_accuracy: 0.7469 - lr: 1.5625e-06
# Epoch 29/50
# 42/42 [==============================] - 2s 41ms/step - loss: 0.3768 - accuracy: 0.8473 - val_loss: 0.5239 - val_accuracy: 0.7474 - lr: 3.9062e-07
# Epoch 30/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3831 - accuracy: 0.8438
# Epoch 30: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3819 - accuracy: 0.8444 - val_loss: 0.5237 - val_accuracy: 0.7465 - lr: 3.9062e-07
# Epoch 31/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3730 - accuracy: 0.8452 - val_loss: 0.5237 - val_accuracy: 0.7465 - lr: 9.7656e-08
# Epoch 32/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3723 - accuracy: 0.8512
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3728 - accuracy: 0.8508 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 9.7656e-08
# Epoch 33/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3750 - accuracy: 0.8473 - val_loss: 0.5236 - val_accuracy: 0.7469 - lr: 2.4414e-08
# Epoch 34/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3733 - accuracy: 0.8491
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3734 - accuracy: 0.8484 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 2.4414e-08
# Epoch 35/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3770 - accuracy: 0.8465 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 6.1035e-09
# Epoch 36/50
# 42/42 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8489
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# 42/42 [==============================] - 2s 41ms/step - loss: 0.3760 - accuracy: 0.8489 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 6.1035e-09
# Epoch 37/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3750 - accuracy: 0.8503 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 1.5259e-09
# Epoch 38/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3747 - accuracy: 0.8537
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3742 - accuracy: 0.8542 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 1.5259e-09
# Epoch 39/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3776 - accuracy: 0.8418 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 3.8147e-10
# Epoch 40/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3732 - accuracy: 0.8548
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3734 - accuracy: 0.8546 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 3.8147e-10
# Epoch 41/50
# 42/42 [==============================] - 2s 42ms/step - loss: 0.3758 - accuracy: 0.8467 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 9.5367e-11
# Epoch 42/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3783 - accuracy: 0.8476
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3794 - accuracy: 0.8467 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 9.5367e-11
# Epoch 43/50
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3751 - accuracy: 0.8484 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 2.3842e-11
# Epoch 44/50
# 41/42 [============================>.] - ETA: 0s - loss: 0.3775 - accuracy: 0.8500
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# 42/42 [==============================] - 2s 38ms/step - loss: 0.3776 - accuracy: 0.8495 - val_loss: 0.5237 - val_accuracy: 0.7469 - lr: 2.3842e-11
# Epoch 44: early stopping

# %%
def cal(y_pred):
  val=[]
  for value in y_pred:
    if value>=0.5:
      val.append(1)
    else:
      val.append(0)
  return val

# %%
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth  
    
    '''
    y_predict = model.predict(test_val)
    y_predict=cal(y_predict)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (5,5))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
y_pred=model_1.predict(test_final_val)
y_pred=cal(y_pred)

# %%
make_confusion_matrix(model_1,y_test,labels=[1, 0])

# %%
from sklearn.preprocessing import LabelEncoder
from keras.initializers import glorot_uniform,glorot_normal
from keras.layers import MaxPooling1D
from keras.layers import concatenate
def Deep_CNN1D(comm_len,token_com,embedding_comm_glove):
    input_1 = Input(shape=(comm_len,),name = 'Text')
    emb_text_layer_1 = Embedding(len(token_com.word_index) + 1,300,weights=[embedding_comm_glove],input_length=comm_len,trainable=False,dtype=tf.float32)(input_1)
    emb_text_layer_1 = Dropout(0.4)(emb_text_layer_1)
    conv1_1 = Conv1D(128,8,1,activation='relu',kernel_initializer=glorot_uniform(seed=42))(emb_text_layer_1)
    max1_1 = MaxPooling1D(pool_size= 4,)(conv1_1)
    conv1_2 = Conv1D(64,4,1,activation='relu',kernel_initializer=glorot_uniform(seed=42))(max1_1)
    max1_2 = MaxPooling1D(4)(conv1_2)
    #lstm_output = LSTM(32, return_sequences = True,name= "LSTM",kernel_initializer=glorot_uniform(seed=42))(max2)
    flatten_1 = Flatten()(max1_2)


    # creating layers for numerical columns
    input_3 = Input(shape=(5,), name = "input_numerical")
    dense_num_layer = Dense(128, activation = "relu")(input_3)

    concatenated_layer = concatenate([flatten_1,dense_num_layer],axis=-1)

    # creating further layers
    y = Dense(2048,activation='relu',kernel_initializer=he_normal(),kernel_regularizer=l2(0.01))(concatenated_layer)
    y = BatchNormalization()(y)
    y=Dropout(0.60)(y)
    y = Dense(1024,activation='relu',kernel_initializer=he_normal(),kernel_regularizer=l2(0.01))(y)
    y = BatchNormalization()(y)
    y=Dropout(0.40)(y)
    y = Dense(512,activation='relu',kernel_initializer=he_normal(),kernel_regularizer=l2(0.01))(y)
    y = BatchNormalization()(y)
    y=Dropout(0.30)(y)
    y = Dense(128,activation='relu',kernel_initializer=he_normal(),kernel_regularizer=l2(0.01))(y)
    y = BatchNormalization()(y)
    y=Dropout(0.20)(y)
    output = Dense(1, activation = 'sigmoid', name= 'model_output',kernel_initializer=glorot_uniform(seed=42))(y)
    model = Model(inputs = [input_1,input_3], outputs = [output])
    return model

# %%
model_2=Deep_CNN1D(comm_len,token_com,embedding_comm_glove)
model_2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text (InputLayer)              [(None, 200)]        0           []
#
#  embedding_1 (Embedding)        (None, 200, 300)     5535300     ['Text[0][0]']
#
#  dropout_1 (Dropout)            (None, 200, 300)     0           ['embedding_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 193, 128)     307328      ['dropout_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 48, 128)     0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 45, 64)       32832       ['max_pooling1d_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 11, 64)      0           ['conv1d_3[0][0]']
#
#  input_numerical (InputLayer)   [(None, 5)]          0           []
#
#  flatten_1 (Flatten)            (None, 704)          0           ['max_pooling1d_3[0][0]']
#
#  dense_5 (Dense)                (None, 128)          768         ['input_numerical[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 832)          0           ['flatten_1[0][0]',
#                                                                   'dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 2048)         1705984     ['concatenate_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2048)        8192        ['dense_6[0][0]']
#  alization)
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['batch_normalization[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         2098176     ['dropout_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 1024)        4096        ['dense_7[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['batch_normalization_1[0][0]']
#
#  dense_8 (Dense)                (None, 512)          524800      ['dropout_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512)         2048        ['dense_8[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 512)          0           ['batch_normalization_2[0][0]']
#
#  dense_9 (Dense)                (None, 128)          65664       ['dropout_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 128)         512         ['dense_9[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 128)          0           ['batch_normalization_3[0][0]']
#
#  model_output (Dense)           (None, 1)            129         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 10,285,829
# Trainable params: 4,743,105
# Non-trainable params: 5,542,724
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model_2, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='TB')

# %%
import tensorflow as tf
adam = tf.keras.optimizers.Adam(lr=0.0001)
model_2.compile(optimizer=adam, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.callbacks import *
import os
earlystop = EarlyStopping(monitor = 'val_accuracy',  mode="max",min_delta = 0, patience = 20,verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.25, patience = 2, verbose = 1)

callbacks = [reduce_lr,earlystop]

# %%
import warnings
warnings.filterwarnings('ignore')
hitory=model_2.fit(x=train_val,y=y_train,epochs=50,batch_size=128,validation_data=(test_val, y_test),callbacks=callbacks)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 5s 59ms/step - loss: 70.9851 - accuracy: 0.5720 - val_loss: 67.6603 - val_accuracy: 0.5206 - lr: 1.0000e-04
# Epoch 2/50
# 42/42 [==============================] - 2s 47ms/step - loss: 64.7873 - accuracy: 0.6358 - val_loss: 61.8329 - val_accuracy: 0.6182 - lr: 1.0000e-04
# Epoch 3/50
# 42/42 [==============================] - 2s 49ms/step - loss: 59.2499 - accuracy: 0.6853 - val_loss: 56.5823 - val_accuracy: 0.7097 - lr: 1.0000e-04
# Epoch 4/50
# 42/42 [==============================] - 2s 46ms/step - loss: 54.2324 - accuracy: 0.7294 - val_loss: 51.7997 - val_accuracy: 0.7697 - lr: 1.0000e-04
# Epoch 5/50
# 42/42 [==============================] - 2s 47ms/step - loss: 49.6517 - accuracy: 0.7583 - val_loss: 47.4271 - val_accuracy: 0.7824 - lr: 1.0000e-04
# Epoch 6/50
# 42/42 [==============================] - 2s 46ms/step - loss: 45.4639 - accuracy: 0.7799 - val_loss: 43.4314 - val_accuracy: 0.7933 - lr: 1.0000e-04
# Epoch 7/50
# 42/42 [==============================] - 2s 46ms/step - loss: 41.6373 - accuracy: 0.7870 - val_loss: 39.7800 - val_accuracy: 0.7982 - lr: 1.0000e-04
# Epoch 8/50
# 42/42 [==============================] - 2s 47ms/step - loss: 38.1420 - accuracy: 0.8032 - val_loss: 36.4472 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 9/50
# 41/42 [============================>.] - ETA: 0s - loss: 34.9768 - accuracy: 0.8108
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 42/42 [==============================] - 2s 46ms/step - loss: 34.9540 - accuracy: 0.8097 - val_loss: 33.4097 - val_accuracy: 0.7968 - lr: 1.0000e-04
# Epoch 10/50
# 42/42 [==============================] - 2s 46ms/step - loss: 33.0613 - accuracy: 0.8142 - val_loss: 32.6908 - val_accuracy: 0.7995 - lr: 2.5000e-05
# Epoch 11/50
# 42/42 [==============================] - 2s 46ms/step - loss: 32.3451 - accuracy: 0.8163 - val_loss: 31.9770 - val_accuracy: 0.7990 - lr: 2.5000e-05
# Epoch 12/50
# 41/42 [============================>.] - ETA: 0s - loss: 31.6396 - accuracy: 0.8173
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 42/42 [==============================] - 2s 46ms/step - loss: 31.6343 - accuracy: 0.8170 - val_loss: 31.2697 - val_accuracy: 0.7995 - lr: 2.5000e-05
# Epoch 13/50
# 42/42 [==============================] - 2s 46ms/step - loss: 31.1844 - accuracy: 0.8225 - val_loss: 31.0931 - val_accuracy: 0.8025 - lr: 6.2500e-06
# Epoch 14/50
# 42/42 [==============================] - 2s 47ms/step - loss: 31.0070 - accuracy: 0.8244 - val_loss: 30.9148 - val_accuracy: 0.8025 - lr: 6.2500e-06
# Epoch 15/50
# 42/42 [==============================] - 2s 46ms/step - loss: 30.8280 - accuracy: 0.8227 - val_loss: 30.7351 - val_accuracy: 0.8030 - lr: 6.2500e-06
# Epoch 16/50
# 42/42 [==============================] - 2s 46ms/step - loss: 30.6477 - accuracy: 0.8307 - val_loss: 30.5543 - val_accuracy: 0.8030 - lr: 6.2500e-06
# Epoch 17/50
# 42/42 [==============================] - 2s 46ms/step - loss: 30.4664 - accuracy: 0.8275 - val_loss: 30.3724 - val_accuracy: 0.8034 - lr: 6.2500e-06
# Epoch 18/50
# 42/42 [==============================] - 2s 46ms/step - loss: 30.2841 - accuracy: 0.8240 - val_loss: 30.1898 - val_accuracy: 0.8017 - lr: 6.2500e-06
# Epoch 19/50
# 41/42 [============================>.] - ETA: 0s - loss: 30.1026 - accuracy: 0.8331
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 42/42 [==============================] - 2s 46ms/step - loss: 30.1012 - accuracy: 0.8332 - val_loss: 30.0066 - val_accuracy: 0.8030 - lr: 6.2500e-06
# Epoch 20/50
# 42/42 [==============================] - 2s 47ms/step - loss: 29.9843 - accuracy: 0.8290 - val_loss: 29.9605 - val_accuracy: 0.8021 - lr: 1.5625e-06
# Epoch 21/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.9384 - accuracy: 0.8239
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 42/42 [==============================] - 2s 47ms/step - loss: 29.9381 - accuracy: 0.8238 - val_loss: 29.9141 - val_accuracy: 0.8025 - lr: 1.5625e-06
# Epoch 22/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.9085 - accuracy: 0.8332 - val_loss: 29.9024 - val_accuracy: 0.8025 - lr: 3.9062e-07
# Epoch 23/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8968 - accuracy: 0.8236
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8967 - accuracy: 0.8240 - val_loss: 29.8906 - val_accuracy: 0.8030 - lr: 3.9062e-07
# Epoch 24/50
# 42/42 [==============================] - 2s 45ms/step - loss: 29.8892 - accuracy: 0.8281 - val_loss: 29.8876 - val_accuracy: 0.8030 - lr: 9.7656e-08
# Epoch 25/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8862 - accuracy: 0.8314
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8862 - accuracy: 0.8311 - val_loss: 29.8846 - val_accuracy: 0.8025 - lr: 9.7656e-08
# Epoch 26/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8843 - accuracy: 0.8305 - val_loss: 29.8839 - val_accuracy: 0.8030 - lr: 2.4414e-08
# Epoch 27/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8835 - accuracy: 0.8253
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8835 - accuracy: 0.8251 - val_loss: 29.8831 - val_accuracy: 0.8025 - lr: 2.4414e-08
# Epoch 28/50
# 42/42 [==============================] - 2s 45ms/step - loss: 29.8830 - accuracy: 0.8287 - val_loss: 29.8829 - val_accuracy: 0.8030 - lr: 6.1035e-09
# Epoch 29/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8828 - accuracy: 0.8251
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# 42/42 [==============================] - 2s 47ms/step - loss: 29.8828 - accuracy: 0.8251 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 6.1035e-09
# Epoch 30/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8358 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 1.5259e-09
# Epoch 31/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8827 - accuracy: 0.8337
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# 42/42 [==============================] - 2s 45ms/step - loss: 29.8827 - accuracy: 0.8326 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 1.5259e-09
# Epoch 32/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8317 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 3.8147e-10
# Epoch 33/50
# 42/42 [==============================] - ETA: 0s - loss: 29.8827 - accuracy: 0.8309
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# 42/42 [==============================] - 2s 49ms/step - loss: 29.8827 - accuracy: 0.8309 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 3.8147e-10
# Epoch 34/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8260 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 9.5367e-11
# Epoch 35/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8827 - accuracy: 0.8356
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8352 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 9.5367e-11
# Epoch 36/50
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8272 - val_loss: 29.8827 - val_accuracy: 0.8030 - lr: 2.3842e-11
# Epoch 37/50
# 41/42 [============================>.] - ETA: 0s - loss: 29.8827 - accuracy: 0.8306
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# 42/42 [==============================] - 2s 46ms/step - loss: 29.8827 - accuracy: 0.8298 - val_loss: 29.8827 - val_accuracy: 0.8025 - lr: 2.3842e-11
# Epoch 37: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(hitory.history['loss'])
plt.plot(hitory.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation f1_score
plt.subplot(122)
plt.plot(hitory.history['accuracy'])
plt.plot(hitory.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
make_confusion_matrix(model_2,y_test,labels=[1, 0])

# %%
model_3=Deep_CNN1D(comm_len,token_com,embedding_comm_wiki)
model_3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Text (InputLayer)              [(None, 200)]        0           []
#
#  embedding_2 (Embedding)        (None, 200, 300)     5535300     ['Text[0][0]']
#
#  dropout_6 (Dropout)            (None, 200, 300)     0           ['embedding_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 193, 128)     307328      ['dropout_6[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 48, 128)     0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 45, 64)       32832       ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 11, 64)      0           ['conv1d_5[0][0]']
#
#  input_numerical (InputLayer)   [(None, 5)]          0           []
#
#  flatten_2 (Flatten)            (None, 704)          0           ['max_pooling1d_5[0][0]']
#
#  dense_10 (Dense)               (None, 128)          768         ['input_numerical[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 832)          0           ['flatten_2[0][0]',
#                                                                   'dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 2048)         1705984     ['concatenate_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 2048)        8192        ['dense_11[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 2048)         0           ['batch_normalization_4[0][0]']
#
#  dense_12 (Dense)               (None, 1024)         2098176     ['dropout_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1024)        4096        ['dense_12[0][0]']
#  rmalization)
#
#  dropout_8 (Dropout)            (None, 1024)         0           ['batch_normalization_5[0][0]']
#
#  dense_13 (Dense)               (None, 512)          524800      ['dropout_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 512)         2048        ['dense_13[0][0]']
#  rmalization)
#
#  dropout_9 (Dropout)            (None, 512)          0           ['batch_normalization_6[0][0]']
#
#  dense_14 (Dense)               (None, 128)          65664       ['dropout_9[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 128)         512         ['dense_14[0][0]']
#  rmalization)
#
#  dropout_10 (Dropout)           (None, 128)          0           ['batch_normalization_7[0][0]']
#
#  model_output (Dense)           (None, 1)            129         ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 10,285,829
# Trainable params: 4,743,105
# Non-trainable params: 5,542,724
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
adam = tf.keras.optimizers.Adam(lr=0.0001)
model_3.compile(optimizer=adam, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
import warnings
warnings.filterwarnings('ignore')
hitory=model_3.fit(x=train_val,y=y_train,epochs=50,batch_size=128,validation_data=(test_val, y_test),callbacks=callbacks)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 4s 57ms/step - loss: 70.9182 - accuracy: 0.5688 - val_loss: 67.4619 - val_accuracy: 0.4295 - lr: 1.0000e-04
# Epoch 2/50
# 42/42 [==============================] - 2s 46ms/step - loss: 64.4733 - accuracy: 0.6027 - val_loss: 61.4038 - val_accuracy: 0.4295 - lr: 1.0000e-04
# Epoch 3/50
# 41/42 [============================>.] - ETA: 0s - loss: 58.7723 - accuracy: 0.6288
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 42/42 [==============================] - 2s 45ms/step - loss: 58.7318 - accuracy: 0.6286 - val_loss: 55.9813 - val_accuracy: 0.4295 - lr: 1.0000e-04
# Epoch 4/50
# 42/42 [==============================] - 2s 46ms/step - loss: 55.3642 - accuracy: 0.6470 - val_loss: 54.7075 - val_accuracy: 0.4326 - lr: 2.5000e-05
# Epoch 5/50
# 42/42 [==============================] - 2s 49ms/step - loss: 54.0953 - accuracy: 0.6540 - val_loss: 53.4442 - val_accuracy: 0.4650 - lr: 2.5000e-05
# Epoch 6/50
# 42/42 [==============================] - 2s 46ms/step - loss: 52.8393 - accuracy: 0.6643 - val_loss: 52.1971 - val_accuracy: 0.5477 - lr: 2.5000e-05
# Epoch 7/50
# 42/42 [==============================] - 2s 47ms/step - loss: 51.6021 - accuracy: 0.6727 - val_loss: 50.9711 - val_accuracy: 0.6423 - lr: 2.5000e-05
# Epoch 8/50
# 42/42 [==============================] - 2s 52ms/step - loss: 50.3874 - accuracy: 0.6866 - val_loss: 49.7687 - val_accuracy: 0.7018 - lr: 2.5000e-05
# Epoch 9/50
# 42/42 [==============================] - 2s 46ms/step - loss: 49.1975 - accuracy: 0.7009 - val_loss: 48.5925 - val_accuracy: 0.7325 - lr: 2.5000e-05
# Epoch 10/50
# 42/42 [==============================] - 2s 45ms/step - loss: 48.0341 - accuracy: 0.7101 - val_loss: 47.4431 - val_accuracy: 0.7518 - lr: 2.5000e-05
# Epoch 11/50
# 42/42 [==============================] - 2s 48ms/step - loss: 46.8980 - accuracy: 0.7153 - val_loss: 46.3210 - val_accuracy: 0.7666 - lr: 2.5000e-05
# Epoch 12/50
# 42/42 [==============================] - 2s 46ms/step - loss: 45.7890 - accuracy: 0.7279 - val_loss: 45.2261 - val_accuracy: 0.7754 - lr: 2.5000e-05
# Epoch 13/50
# 42/42 [==============================] - 2s 46ms/step - loss: 44.7072 - accuracy: 0.7399 - val_loss: 44.1581 - val_accuracy: 0.7833 - lr: 2.5000e-05
# Epoch 14/50
# 42/42 [==============================] - 2s 47ms/step - loss: 43.6522 - accuracy: 0.7497 - val_loss: 43.1168 - val_accuracy: 0.7920 - lr: 2.5000e-05
# Epoch 15/50
# 42/42 [==============================] - 2s 46ms/step - loss: 42.6233 - accuracy: 0.7562 - val_loss: 42.1009 - val_accuracy: 0.7947 - lr: 2.5000e-05
# Epoch 16/50
# 42/42 [==============================] - 2s 49ms/step - loss: 41.6193 - accuracy: 0.7540 - val_loss: 41.1098 - val_accuracy: 0.7960 - lr: 2.5000e-05
# Epoch 17/50
# 42/42 [==============================] - 2s 46ms/step - loss: 40.6402 - accuracy: 0.7632 - val_loss: 40.1432 - val_accuracy: 0.7986 - lr: 2.5000e-05
# Epoch 18/50
# 42/42 [==============================] - 2s 46ms/step - loss: 39.6853 - accuracy: 0.7737 - val_loss: 39.2007 - val_accuracy: 0.8004 - lr: 2.5000e-05
# Epoch 19/50
# 42/42 [==============================] - 2s 46ms/step - loss: 38.7540 - accuracy: 0.7720 - val_loss: 38.2814 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 20/50
# 42/42 [==============================] - 2s 46ms/step - loss: 37.8460 - accuracy: 0.7774 - val_loss: 37.3851 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 21/50
# 42/42 [==============================] - 2s 46ms/step - loss: 36.9604 - accuracy: 0.7829 - val_loss: 36.5111 - val_accuracy: 0.8065 - lr: 2.5000e-05
# Epoch 22/50
# 42/42 [==============================] - 2s 47ms/step - loss: 36.0969 - accuracy: 0.7812 - val_loss: 35.6587 - val_accuracy: 0.8087 - lr: 2.5000e-05
# Epoch 23/50
# 42/42 [==============================] - 2s 47ms/step - loss: 35.2551 - accuracy: 0.7904 - val_loss: 34.8280 - val_accuracy: 0.8078 - lr: 2.5000e-05
# Epoch 24/50
# 41/42 [============================>.] - ETA: 0s - loss: 34.4406 - accuracy: 0.7965
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 42/42 [==============================] - 2s 46ms/step - loss: 34.4344 - accuracy: 0.7979 - val_loss: 34.0180 - val_accuracy: 0.8034 - lr: 2.5000e-05
# Epoch 25/50
# 42/42 [==============================] - 2s 48ms/step - loss: 33.9214 - accuracy: 0.7943 - val_loss: 33.8183 - val_accuracy: 0.8095 - lr: 6.2500e-06
# Epoch 26/50
# 42/42 [==============================] - 2s 45ms/step - loss: 33.7218 - accuracy: 0.8005 - val_loss: 33.6188 - val_accuracy: 0.8117 - lr: 6.2500e-06
# Epoch 27/50
# 42/42 [==============================] - 2s 48ms/step - loss: 33.5222 - accuracy: 0.7945 - val_loss: 33.4192 - val_accuracy: 0.8135 - lr: 6.2500e-06
# Epoch 28/50
# 42/42 [==============================] - 2s 48ms/step - loss: 33.3226 - accuracy: 0.7953 - val_loss: 33.2197 - val_accuracy: 0.8122 - lr: 6.2500e-06
# Epoch 29/50
# 42/42 [==============================] - 2s 46ms/step - loss: 33.1232 - accuracy: 0.7943 - val_loss: 33.0203 - val_accuracy: 0.8139 - lr: 6.2500e-06
# Epoch 30/50
# 42/42 [==============================] - 2s 45ms/step - loss: 32.9240 - accuracy: 0.8052 - val_loss: 32.8214 - val_accuracy: 0.8126 - lr: 6.2500e-06
# Epoch 31/50
# 42/42 [==============================] - ETA: 0s - loss: 32.7252 - accuracy: 0.7998
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 42/42 [==============================] - 2s 46ms/step - loss: 32.7252 - accuracy: 0.7998 - val_loss: 32.6227 - val_accuracy: 0.8135 - lr: 6.2500e-06
# Epoch 32/50
# 42/42 [==============================] - 2s 45ms/step - loss: 32.5986 - accuracy: 0.8035 - val_loss: 32.5729 - val_accuracy: 0.8130 - lr: 1.5625e-06
# Epoch 33/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.5491 - accuracy: 0.8068
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 42/42 [==============================] - 2s 45ms/step - loss: 32.5488 - accuracy: 0.8060 - val_loss: 32.5229 - val_accuracy: 0.8130 - lr: 1.5625e-06
# Epoch 34/50
# 42/42 [==============================] - 2s 46ms/step - loss: 32.5169 - accuracy: 0.8003 - val_loss: 32.5104 - val_accuracy: 0.8122 - lr: 3.9062e-07
# Epoch 35/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.5044 - accuracy: 0.7978
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 42/42 [==============================] - 2s 52ms/step - loss: 32.5043 - accuracy: 0.7990 - val_loss: 32.4977 - val_accuracy: 0.8117 - lr: 3.9062e-07
# Epoch 36/50
# 42/42 [==============================] - 2s 46ms/step - loss: 32.4962 - accuracy: 0.8013 - val_loss: 32.4946 - val_accuracy: 0.8117 - lr: 9.7656e-08
# Epoch 37/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.4930 - accuracy: 0.8032
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 42/42 [==============================] - 2s 48ms/step - loss: 32.4930 - accuracy: 0.8037 - val_loss: 32.4914 - val_accuracy: 0.8126 - lr: 9.7656e-08
# Epoch 38/50
# 42/42 [==============================] - 2s 45ms/step - loss: 32.4910 - accuracy: 0.8007 - val_loss: 32.4906 - val_accuracy: 0.8126 - lr: 2.4414e-08
# Epoch 39/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.4902 - accuracy: 0.7948
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# 42/42 [==============================] - 2s 45ms/step - loss: 32.4902 - accuracy: 0.7945 - val_loss: 32.4897 - val_accuracy: 0.8126 - lr: 2.4414e-08
# Epoch 40/50
# 42/42 [==============================] - 2s 48ms/step - loss: 32.4897 - accuracy: 0.8032 - val_loss: 32.4896 - val_accuracy: 0.8122 - lr: 6.1035e-09
# Epoch 41/50
# 42/42 [==============================] - ETA: 0s - loss: 32.4895 - accuracy: 0.8007
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# 42/42 [==============================] - 2s 52ms/step - loss: 32.4895 - accuracy: 0.8007 - val_loss: 32.4894 - val_accuracy: 0.8126 - lr: 6.1035e-09
# Epoch 42/50
# 42/42 [==============================] - 2s 46ms/step - loss: 32.4893 - accuracy: 0.7998 - val_loss: 32.4893 - val_accuracy: 0.8126 - lr: 1.5259e-09
# Epoch 43/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.4893 - accuracy: 0.8054
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# 42/42 [==============================] - 2s 45ms/step - loss: 32.4893 - accuracy: 0.8052 - val_loss: 32.4893 - val_accuracy: 0.8130 - lr: 1.5259e-09
# Epoch 44/50
# 42/42 [==============================] - 2s 45ms/step - loss: 32.4893 - accuracy: 0.8003 - val_loss: 32.4893 - val_accuracy: 0.8135 - lr: 3.8147e-10
# Epoch 45/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.4893 - accuracy: 0.8014
# Epoch 45: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# 42/42 [==============================] - 2s 45ms/step - loss: 32.4893 - accuracy: 0.8020 - val_loss: 32.4893 - val_accuracy: 0.8126 - lr: 3.8147e-10
# Epoch 46/50
# 42/42 [==============================] - 2s 47ms/step - loss: 32.4893 - accuracy: 0.8058 - val_loss: 32.4893 - val_accuracy: 0.8126 - lr: 9.5367e-11
# Epoch 47/50
# 41/42 [============================>.] - ETA: 0s - loss: 32.4893 - accuracy: 0.8016
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# 42/42 [==============================] - 2s 46ms/step - loss: 32.4893 - accuracy: 0.8011 - val_loss: 32.4893 - val_accuracy: 0.8126 - lr: 9.5367e-11
# Epoch 48/50
# 42/42 [==============================] - 2s 46ms/step - loss: 32.4893 - accuracy: 0.8011 - val_loss: 32.4893 - val_accuracy: 0.8130 - lr: 2.3842e-11
# Epoch 49/50
# 42/42 [==============================] - ETA: 0s - loss: 32.4893 - accuracy: 0.8058
# Epoch 49: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# 42/42 [==============================] - 2s 46ms/step - loss: 32.4893 - accuracy: 0.8058 - val_loss: 32.4893 - val_accuracy: 0.8130 - lr: 2.3842e-11
# Epoch 49: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(hitory.history['loss'])
plt.plot(hitory.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation f1_score
plt.subplot(122)
plt.plot(hitory.history['accuracy'])
plt.plot(hitory.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
make_confusion_matrix(model_3,y_test,labels=[1, 0])

# %%
y_pred=model_3.predict(test_final_val)
y_pred=cal(y_pred)

# %%
submission=pd.read_csv('/content/drive/MyDrive/Tweets Disaster /sample_submission.csv')
submission.head()
# Out:
#    id  target
# 0   0       0
# 1   2       0
# 2   3       0
# 3   9       0
# 4  11       0

# %%
submission['target']=y_pred
submission.to_csv('final_CNN_submission_1.csv',index=False)
